# %%
import pandas as pd
x_test=pd.read_csv("/media/adesh/Volume D/DataSets-master/loan_prediction-1/X_test.csv")
y_test=pd.read_csv("/media/adesh/Volume D/DataSets-master/loan_prediction-1/Y_test.csv")
x_train=pd.read_csv("/media/adesh/Volume D/DataSets-master/loan_prediction-1/X_train.csv")
y_train=pd.read_csv("/media/adesh/Volume D/DataSets-master/loan_prediction-1/Y_train.csv")

# %%
x_train
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001032   Male      No          0      Graduate            No
# 1    LP001824   Male     Yes          1      Graduate            No
# 2    LP002928   Male     Yes          0      Graduate            No
# 3    LP001814   Male     Yes          2      Graduate            No
# 4    LP002244   Male     Yes          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 379  LP002585   Male     Yes          0      Graduate            No
# 380  LP001841   Male      No          0  Not Graduate           Yes
# 381  LP002820   Male     Yes          0      Graduate            No
# 382  LP001744   Male      No          0      Graduate            No
# 383  LP001552   Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               4950                0.0         125               360
# ...

# %%
x_train["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
x_train_cat=x_train[['Gender', 'Married', 'Education',
       'Self_Employed', 'Property_Area','Dependents']]

# %%
x_train.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
x_train_cat
# Out:
#      Gender  Married  Education  Self_Employed  Property_Area Dependents
# 0         1        0          0              0              2          0
# 1         1        1          0              0              1          1
# 2         1        1          0              0              1          0
# 3         1        1          0              0              2          2
# 4         1        1          0              0              2          0
# ..      ...      ...        ...            ...            ...        ...
# 379       1        1          0              0              0          0
# 380       1        0          1              1              0          0
# 381       1        1          0              0              0          0
# 382       1        0          0              0              1          0
# 383       1        1          0              0              1          0
#
# [384 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()
for i in x_train_cat.columns:
    x_train[i]=lb.fit_transform(x_train[i])

# %%
x_train_w_id=x_train.drop("Loan_ID",axis=1)

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x_train[["ApplicantIncome" ,"CoapplicantIncome" ,"LoanAmount","Loan_Amount_Term"]]=ss.fit_transform(x_train[["ApplicantIncome" ,"CoapplicantIncome" ,"LoanAmount","Loan_Amount_Term"]])

# %%
x_train_w_id
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0        -0.037697
# 1         1        1          1          0              0        -0.428032
# 2         1        1          0          0              0        -0.405760
# 3         1        1          2          0              0         0.859432
# 4         1        1          0          0              0        -0.531656
# ..      ...      ...        ...        ...            ...              ...
# 379       1        1          0          0              0        -0.293076
# 380       1        0          0          1              1        -0.484468
# 381       1        1          0          0              0         0.145957
# 382       1        0          0          0              0        -0.411233
# 383       1        1          0          0              0        -0.106968
#
# ...

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
score=cross_val_score(lr,x_train_w_id,y_train,scoring="neg_mean_squared_error",cv=10)

# %%
y_train=lb.fit_transform(y_train)

# %%
import numpy as np
rmse=np.sqrt(-score)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()

# %%
score_1=cross_val_score(dtc,x_train_w_id,y_train,scoring="neg_mean_squared_error",cv=10)

# %%
rmse=np.sqrt(-score_1)

# %%
rmse
# Out:
# array([0.54772256, 0.531085  , 0.48038446, 0.62828086, 0.45883147,
#        0.51298918, 0.39735971, 0.51298918, 0.53802759, 0.53802759])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rtc=RandomForestClassifier()
score_2=cross_val_score(rtc,x_train_w_id,y_train,scoring="neg_mean_squared_error",cv=10)
rmse_2=np.sqrt(-score_2)
# Out:
# /home/adesh/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/adesh/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/adesh/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/adesh/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ...

# %%
rmse_2
# Out:
# array([0.4472136 , 0.45291081, 0.32025631, 0.51298918, 0.45883147,
#        0.45883147, 0.45883147, 0.48666426, 0.53802759, 0.48666426])
